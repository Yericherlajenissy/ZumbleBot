# %%
# !pip install gradio_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.2/322.2 kB 7.0 MB/s eta 0:00:00
# ...

# %%
from gradio_client import Client

client = Client("Martim-Ramos-Neural/AnimateDiffPipeline_text_to_video")
result = client.predict(
		prompt="Hello!!",
		base="Realistic",
		motion="guoyww/animatediff-motion-lora-zoom-in",
		step="4",
		resolution="Square",
		api_name="/instant_video"
)
print(result)
# Out:
# Loaded as API: https://martim-ramos-neural-animatediffpipeline-text-to-video.hf.space ✔
# ---------------------------------------------------------------------------
# AppError                                  Traceback (most recent call last)
# <ipython-input-3-ac97de6aaca6> in <cell line: 0>()
#       2
#       3 client = Client("Martim-Ramos-Neural/AnimateDiffPipeline_text_to_video")
# ----> 4 result = client.predict(
#       5                 prompt="Hello!!",
#       6                 base="Realistic",
#
# /usr/local/lib/python3.11/dist-packages/gradio_client/client.py in predict(self, api_name, fn_index, *args, **kwargs)
#     476         return self.submit(
#     477             *args, api_name=api_name, fn_index=fn_index, **kwargs
# --> 478         ).result()
#     479
#     480     def new_helper(self, fn_index: int) -> Communicator:
#
# /usr/local/lib/python3.11/dist-packages/gradio_client/client.py in result(self, timeout)
#    1537             >> 9
#    1538         """
# ...

# %%
from gradio_client import Client

client = Client("https://bdc-divya-gradio-text-to-audio-generator.hf.space/--replicas/fackn/")
result = client.predict(
		"Hello!!",	# str  in 'description' Textbox component
							api_name="/predict"
)
print(result)
# Out:
# Loaded as API: https://bdc-divya-gradio-text-to-audio-generator.hf.space/--replicas/fackn/ ✔
# /tmp/gradio/0bd33c180513652723e5958a89aeb50317d83b406fbe865558d4c0af2f1aade7/bf89a52a-1df5-11f0-a337-0edd1d00104c.wav
